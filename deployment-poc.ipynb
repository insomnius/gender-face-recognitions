# %%
from tensorflow.keras.models import Sequential, load_model
import tensorflowjs as tfjs
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Sequential, load_model

# %%
# loading keras model
keras_model = load_model('output/inceptionV3-iteration-1.keras')

# convert keras model to h5
# keras_model.save('output/inceptionResNetV2-iteration-3.h5')
# h5_model = load_model('output/inceptionResNetV2-iteration-3.h5')

# convert keras model to tfjs format
# tfjs.converters.save_keras_model(keras_model, 'output/')

# models = {
#   'keras': keras_model,
#   'h5': h5_model
# }
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/keras/src/saving/serialization_lib.py:789, in _retrieve_class_or_fn(name, registered_name, module, obj_type, full_config, custom_objects)
#     788 try:
# --> 789     mod = importlib.import_module(module)
#     790 except ModuleNotFoundError:
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1126, in _find_and_load_unlocked(name, import_)
#
# ...
